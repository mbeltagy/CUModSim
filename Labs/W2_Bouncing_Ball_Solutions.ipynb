# %% [markdown]
# # The Bouncing Ball introduction to Modeling and Simulation
# Last week we spend a great deal of time in the class discussing the bouncing
# ball model, Julia, and different ways of modeling as well and writing Julia
# code. In the notebook we intend the wrap up the discussion about that particular
# model and what we can learn from it as we approach other modeling and simulation
# tasks.

# %% [markdown]
# ## The physics of a bouncing ball
#
# From our basic classroom physics we know that a ball in a state of rest (i.e. zero velocity) that
# is released from height $h_0$ will drop towards the ground with acceleration with an acceleration
# due to gravity $g$, that usually has the value of $9.81 m/s^2$. However, when making that
# simple statement we must be aware of the implicit assumptions that this entails:
# - There are no fluid effects such as *bouyancy* or *drag*.
# - We are on planet earth and somewhere near its surface, and on an altitude and latitude
#     where $g=9.81 m/s^2$ is an okay approximation
#     (we know that is on our planet is could anywhere from $9.764 m/s^2$ to $9.834 m/s^2$).
# - The diameter, mass, and color of the ball does not matter
# - The ball is perfectly spherical and the ground is perfectly flat and level (so that when dropped from rest, it will bounce perfectly upwards)
#
# <span style="color:red">**Lesson 1: Always state your assumptions**</span>
#
# Having stated our assumption we now proceed with the equations of motion. We
# know that a ball dropped from rest (in a vacuum, or with negligible fluid
# effects), will be subject to [constant translational acceleration in a straight
# line](https://en.wikipedia.org/wiki/Equations_of_motion#Uniform_acceleration).
#
# Hence
# $$v=v_0-g t$$
# Here $v$ is the vertical velocity, and v_0 is the initial vertical velocity. Our coordinate system is oriented such that
# the positive sense is away from the surface of the earth, hence the -ve effect
# of earth's acceleration. We can integrate the above equation to find the hight
# of the ball. It will come to
# $$h=h_o+v_0t -\frac{1}{2}gt^2$$
# Where $h$ is the vertical hight above ground and $h_0$ is the initial hight.
# We know that when the ball hits the ground, it will lose some energy on the
# bounce. This can be expressed as
# $$v_a=-c v_b$$
# Where $v_b$ is the velocity immediately prior to collision, $v_a$ is the velocity immediately after collision,and  $c$ is the [coefficient or restitution](https://en.wikipedia.org/wiki/Coefficient_of_restitution).

# %% [markdown]
# ## The Model of the bouncing ball
# We have to be careful here stating the governing equations does not fully
# capture the model. We have to be aware of the _discontinuities_ that happen in
# our model. Things change before and after each bounce.
#
# We start by considering what happens in when we release the ball from rest up
# up until it hits the ground. Since it is released from the question for velocity
# will be simplified to
# $$v=-g t$$
# and for the height, it will be
# $$h=h_o-\frac{1}{2}gt^2$$
# We know it will hit the ground when $h=0$. A bit of algebra, will show us that
# it hit ground at time
# $$t_1=\sqrt{\frac{2h_0}{g}}$$
# The subscript $t_i$ indicates the $i$th time the ball will hit the ground. The
# velocity immediately before the bounce, will hence be
# $$v_b=-gt_1=-\sqrt{2h_0g}$$. The velocity immediately after the first bounce
# will be
# $$v_1=c\sqrt{2h_0g}$$
# where $v_i$  is the vertical velocity after the $i$th bounce.
#
# It is important to note that after the bounce the is change of force therefore a
# discontinuity in the meaning of time in equations of motion. The equations stated in the previous
# section will still hold, however the time $t$ will _reset_. Hence after the
# bounce
# $$v=v_1-g t$$
# and
# $$h=v_1t -\frac{1}{2}gt^2$$
# where the time variable $t$ above denotes the time _after_ $t_1$. If we prefer
# to express the equations of motion in absolute time time after the ball has been
# released, we can write the above two equations as
# $$v=v_1-g (t-t_1)$$
# and
# $$h=v_1(t-t_1) -\frac{1}{2}g(t-t_1)^2$$
#
# We can now substitute $h=0$ is and we find
# $$t_2-t_1=\frac{2v_1}{g}$$
# also
# $$v_2=c v_1$$
#
# We can express this in very general terms as
# $$t_{i+1}-t_i=\frac{2v_i}{g}$$
# and
# $$v_{i+1}=c v_i=c^iv_1$$
# Also in general term, we can rewrite the equation of motion as
# $$h(t)=\begin{cases}
#     h_o-\frac{1}{2}gt^2,& \text{if } 0<t\leq t_1\\
#     v_i(t-t_i) -\frac{1}{2}g(t-t_i)^2,& \text{for } t_i<t\leq t_{i+1}
# \end{cases}$$
# In conclusion, we only need to calculate $t_1$ and $v_1$ to start with, then we
# need to calculate all subsequent $v_i$s and $t_i$s and used the appropriate
# equation for the hight calculation.  We are now ready to start doing our
# simulation.

# %% [markdown]
# ## Bouncing Ball Simulation

# %%
using Winston # For plotting

# %%
"""
Given initial hight h0 and coefficient or restitution c, the function 
will generate a vector of ball postions up until time end_t. 
"""
function bouncingBallPositon1(h0,c,end_t, delta=0.01)
    g=9.81 # we will have this fixed
    t1=ti=t_next=sqrt(2*h0/g)
    vi=sqrt(2*h0*g) #Just before the bounce 
    time_range=0:delta:end_t
    h_vec=zeros(length(time_range)) #The hight vector 
    i=1 # Array Index
    for t in time_range
        if t<=t1
            h_vec[i]=h0-0.5*g*t^2
        else
            if t>t_next #t_next is t_{i+1} in the equations
                ti=t_next
                vi*=c
                t_next+=2*vi/g
            end
            h_vec[i]=vi*(t-ti)-0.5*g*(t-ti)^2
        end
        i+=1 # Incrementing the array counter 
    end
    h_vec # return the vector of heights 
end
# Out:
# bouncingBallPositon1

# %%
h_vec=bouncingBallPositon1(1,0.8,3.0)
plot(0:0.01:3,h_vec)
xlabel("Time")
ylabel("Height")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# ## Lab tasks
# 1. What is the _qualitative_ relationship between drop in hight after each bounce and $c$?
# 2. Plot the drop in maximum hight over time for a given $c$ and h.
# 3. Plot the relationship between $c$ and the time it take for the ball ball to have a maximum hight less than 1cm
# 4. Plot the relationship between $h_0$ and the time it take for the ball ball to have a maximum hight less than 1cm
# 5. Earlier attempts at the problem (see some of the group's posts) attempted to solve this problem by detecting the bounce when the hight starts to go below zero. How is the approach presented here better or worse?

# %% [markdown]
# ### What is the _qualitative_ relationship between drop in hight after each bounce and $c$?
# In order to do that, it might be a good idea to do multiple plots with different $c$ values. We try here the values of 0.3, 0.5,0.8

# %%
h_vec_1=bouncingBallPositon1(1,0.3,3.0)
h_vec_2=bouncingBallPositon1(1,0.5,3.0)
h_vec_3=bouncingBallPositon1(1,0.8,3.0)
t_range=0:0.01:3
plot(t_range,h_vec_1,t_range,h_vec_2,t_range, h_vec_3)
xlabel("Time")
ylabel("Height")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# We see that we probably broke the code as we are getting -ve hieghts. That should never be. The reason why that is the case is because we ran into a situation where
# $$v_i \approx 0$$
# To avoide that, we have to check if for it in the code.

# %%
function bouncingBallPositon2(h0,c,end_t, delta=0.01)
    g=9.81 # we will have this fixed
    t1=ti=t_next=sqrt(2*h0/g)
    vi=sqrt(2*h0*g) #Just before the bounce 
    time_range=0:delta:end_t
    h_vec=zeros(length(time_range)) #The hight vector 
    i=1 # Array Index
    for t in time_range
        if t<=t1
            h_vec[i]=h0-0.5*g*t^2
        else
            if t>t_next #t_next is t_{i+1} in the equations
                ti=t_next
                vi*=c
                t_next+=2*vi/g
            end
            if vi<0.0001  # Checking if the velocity if really small
               h_vec[i]=0
            else
              h_vec[i]=max(vi*(t-ti)-0.5*g*(t-ti)^2,0)
            end
        end
        i+=1 # Incrementing the array counter 
    end
    h_vec # return the vector of heights 
end
# Out:
# bouncingBallPositon2 (generic function with 2 methods)

# %%
h_vec_1=bouncingBallPositon2(1,0.3,3.0) # Black
h_vec_2=bouncingBallPositon2(1,0.5,3.0) # Red
h_vec_3=bouncingBallPositon2(1,0.8,3.0) # Green 
t_range=0:0.01:3
plot(t_range,h_vec_1,t_range,h_vec_2,t_range, h_vec_3)
xlabel("Time")
ylabel("Height")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# From the above we conclude that: lower value of $c$ results in smaller bounce hights.

# %% [markdown]
# ### Plot the drop in maximum hight over time for a given $c$ and h.
# There is two ways going about this.
# 1. Purely emprical
# 2. We use some mathematical insight
#
# If we are not so gifter we start with 1

# %%
"""
Given the history of ball hight h_vec and time range t_range, 
we return a vector of maximum hights and vector oftimes in which 
they occured 
"""
function findmax_hights_times(t_range,h_vec)
    m_hights=Float64[1.0]
    m_times=Float64[0.0]
    for i=2:length(t_range)-1
        #find max points 
        if h_vec[i]>h_vec[i-1] && h_vec[i]>h_vec[i+1]
            push!(m_times,t_range[i])
            push!(m_hights,h_vec[i])
        end
    end
    m_times, m_hights 
end
# Out:
# findmax_hights_times

# %%
m_times_1,m_hights_1=findmax_hights_times(t_range,h_vec_3)
plot(m_times_1,m_hights_1, "*")
xlabel("Time")
ylabel("Height")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# The more mathmatical approach if to find equations for getting the maximum hights and corresponding times. We do that by considering the velocity equation
# $$v=v_i-g (t-t_i)$$
# and find the time at which $v=0$. This will be
# $$\tilde{t}_i=\frac{v_i}{g}+t_i$$
#
# and after some algebra, this will result in
# $$\tilde{h}_i=\frac{v_i^2}{2g}$$
#
# We are now ready to code a function to do just that

# %%
"""
Given initial hight h0 and coefficient or restitution c, the function 
will generate a vector maximum ball heights and a vector correspoing times
up until time end_t. 
"""
function findmax_hights_times(h0,c,end_t)
    g=9.81 # we will have this fixed
    m_hights=Float64[1.0]
    m_times=Float64[0.0]
    ti=sqrt(2*h0/g)
    vi=c*sqrt(2*h0*g) #Just after the bounce 
    while ti<end_t
        t_max=vi/g+ti
        h_max=vi^2/(2*g)
        push!(m_hights,h_max)
        push!(m_times,t_max)
        ti+=2*vi/g
        vi*=c
        if vi<0.0001
            break
        end
    end
    m_times, m_hights 
end
# Out:
# WARNING: Method definition findmax_hights_times(Any, Any, Any) in module Main at In[11]:7 overwritten at In[15]:7.
# WARNING: replacing docs for 'findmax_hights_times :: Tuple{Any,Any,Any}' in module 'Main'.
# findmax_hights_times

# %%
m_times_2,m_hights_2=findmax_hights_times(1.0,0.8,3.0)
plot(m_times_2,m_hights_2, "*")
xlabel("Time")
ylabel("Height")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# We can compare both approaches

# %%
plot(m_times_1,m_hights_1, "*",m_times_2,m_hights_2, "*")
xlabel("Time");ylabel("Height")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# We see that they are perfectly identical. Another means of verification is to see that calcuation on the original image of hights.

# %%
plot(t_range, h_vec_3,m_times_2,m_hights_2, "*")
xlabel("Time");ylabel("Height")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# ### Plot the relationship between $c$ and the time it take for the ball ball to have a maximum hight less than 1cm
# Again we can follow a more emprical approach or one the immediatly calcultes the maximum hight directly. We will opt for the later.

# %%
function time_for_1cm_max_hight(h0,c)
    g=9.81 # we will have this fixed
    ti=sqrt(2*h0/g)
    vi=c*sqrt(2*h0*g) #Just after the bounce 
    while true
        t_max=vi/g+ti
        h_max=vi^2/(2*g)
        if h_max<0.01
            break
        end
        ti+=2*vi/g
        vi*=c
   end
   t_max
end
# Out:
# time_for_1cm_max_hight (generic function with 1 method)

# %%
time_for_1cm_max_hight(1.0,0.8)
# Out:
# 3.6758569145906668

# %%
c_vec=[0.3:0.1:0.9...]
t_vec=[time_for_1cm_max_hight(1.0,c) for c in c_vec]
plot(c_vec,t_vec,"*")
xlabel("Coefficient of restitution");ylabel("Time to max hight 1cm")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# ###  Plot the relationship between $h_0$ and the time it take for the ball ball to have a maximum hight less than 1cm
# We just reuse the function we just designed

# %%
h0_vec=[0.2:0.1:5...]
t_vec=[time_for_1cm_max_hight(h0,0.3) for h0 in h0_vec]
plot(h0_vec,t_vec,"*")
xlabel("Max drop hight");ylabel("Time to max hight 1cm")
# Out:
# Winston.FramedPlot(...)

# %% [markdown]
# We see a bit of dicontinuity here. Can we tell why? It is because the time returned is $t_i$ and we can have cycle flip here.

# %% [markdown]
# ### Earlier attempts at the problem (see some of the group's posts) attempted to solve this problem by detecting the bounce when the hight starts to go below zero. How is the approach presented here better or worse?
#
# The approach presented here is more accurate and is less subject od numerical drift with changing time steps. An emperical comparison between both can show that.
